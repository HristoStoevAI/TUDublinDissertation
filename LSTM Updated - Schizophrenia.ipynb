# %%
import numpy
from keras import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import StandardScaler


import os
import pandas as pd
import numpy as np
from time import time as t
from sklearn.metrics import classification_report
import h5py
from keras import optimizers
from keras import callbacks
import time
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import ParameterGrid

# %%
from keras import backend as K

def tp_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    return true_positives
    
def fp_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return predicted_positives-true_positives

def tn_m(y_true, y_pred):
    print('y_true - 1 '+str((y_true-1)))
    false_negatives = K.sum(K.round(K.clip((y_true-1) * (y_pred-1), 0, 1)))
    return false_negatives
    
def fn_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return possible_positives-true_positives

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
numpy.random.seed(0)

# %%
n_splits=4
train_size=0.8
test_size=0.2

# %%
class EEGSchizoDatasetBalanced():
    """EEG Alco Train dataset."""

    def __init__(self):
        """
        Args:
            none.
        """
        h5f = h5py.File('schizo_scalars_unbalanced.h5','r')
        self.spikes_seizure_eeg = h5f['dataset_schizo_scalars_unbalanced'][:]
        self.spikes_seizure_eeg=np.swapaxes(self.spikes_seizure_eeg,1,2)


        scalers = {}        
        for i in range(self.spikes_seizure_eeg.shape[1]):
            scalers[i] = StandardScaler()
            self.spikes_seizure_eeg[:, i, :] = scalers[i].fit_transform(self.spikes_seizure_eeg[:, i, :]) 

        h5f.close()
        
        h5f = h5py.File('schizo_labels_unbalanced.h5','r')
        self.labels_seizure_eeg = h5f['dataset_schizo_labels_unbalanced'][:]
        print(str(np.sum(self.labels_seizure_eeg))+'/'+str(len(self.labels_seizure_eeg)))
        h5f.close()
        
    def get_data(self):
        #all folds
        dataArray = list()
        sss = StratifiedShuffleSplit(n_splits=n_splits, train_size=train_size, test_size=test_size, random_state=0)
        for train_index, test_index in sss.split(self.spikes_seizure_eeg, self.labels_seizure_eeg):
            
            trainLabels=self.labels_seizure_eeg[train_index]
            trainValues=self.spikes_seizure_eeg[train_index]
            testLabels=self.labels_seizure_eeg[test_index]
            testValues=self.spikes_seizure_eeg[test_index]

            #BALANCING TRAINING DATA
            positivesIndices=trainLabels==1
            positiveEEGs=trainValues[positivesIndices]
            negativeEEGs=trainValues[~positivesIndices]
            print('positiveEEGs: '+str(len(positiveEEGs)))
            print('negativeEEGs: '+str(len(negativeEEGs)))

            n=np.min([len(positiveEEGs),len(negativeEEGs)])
            print(n)

            trainValues=(np.concatenate((positiveEEGs[0:n],negativeEEGs[0:n]),axis=0))
            trainLabels=(np.concatenate((np.full((n),1),np.full((n),0)),axis=0))
            
            shuffle = np.random.RandomState(seed=0).permutation(len(trainValues))
            trainValues = trainValues[shuffle]
            trainLabels = trainLabels[shuffle]
            currentSplit = {'X_train': (trainValues), 'X_test': (testValues), 
                            'y_train': (trainLabels), 'y_test': (testLabels)}
            dataArray.append(currentSplit)
        return dataArray

    def __len__(self):
        return len(self.spikes_seizure_eeg)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        eeg = torch.tensor(self.spikes_seizure_eeg[idx])
        print('eeg size (in getitem): '+str(eeg.size()))
        label = self.labels_seizure_eeg[idx]
            
        sample = {'eeg': eeg, 'label': label}
        return sample

# %%
seizureDataset = EEGSchizoDatasetBalanced()
dataArray = seizureDataset.get_data()
# Out:
# 45/84
# positiveEEGs: 36
# negativeEEGs: 31
# 31
# positiveEEGs: 36
# negativeEEGs: 31
# 31
# positiveEEGs: 36
# negativeEEGs: 31
# 31
# positiveEEGs: 36
# negativeEEGs: 31
# 31

# %%
starting_point = 0

# %%
data = 'schizo_lstm'

# %%
class TimeHistory(callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()
        print('epoch time start: '+str(self.epoch_time_start))

    def on_epoch_end(self, batch, logs={}):
        end_time = time.time() - self.epoch_time_start
        self.times.append(end_time)
        print('epoch time measured: '+str(end_time))

class TestMetricsCallback(callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs={}):
        x, y = self.test_data
        loss, acc = self.model.evaluate(x, y, verbose=0)
        print('\nTesting loss: {}, acc: {}\n'.format(loss, acc))

# %%
n_epochs=250

# %%
resultsFilename = str(data)+"_results_data_FINAL.txt"

if os.path.isfile(resultsFilename):
    print ("Results file exists")
else:
    print ("Results file doesn't exist, creating new file...")


overallPrecisionList = list()
overallRecallList = list()
overallAccuracyList = list()
overallF1List = list()
overallTPList = list()
overallTNList = list()
overallFPList = list()
overallFNList = list()
overallConvergenceEpochList = list()
overallTrainingTimeList = list()
overallMeanEpochTimeList = list()


with open(resultsFilename, "a") as text_file:
    print(f"Test Results :\n\n", file=text_file)
for fold in np.arange(n_splits):
    early_stopping_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=250)
    checkpoint_callback = ModelCheckpoint('optimal_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
    currentFold = fold
    # Train the network.
    print("Begin training for fold " + str(currentFold) + "\n")
    start = t()
    # create the model
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, 
                   input_shape=(16, 7680), activation='sigmoid'))
    #model.add(Dropout(0.2))
    model.add(LSTM(128, activation='sigmoid'))
    #model.add(Dropout(0.2))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    optimizer = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999)

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy',f1_m,precision_m, recall_m, tp_m, fp_m, tn_m, fn_m])
    print(model.summary())
    time_callback = TimeHistory()
    print('input data shape: '+str(dataArray[currentFold]['X_train'].shape))


    modelHistory=model.fit(dataArray[currentFold]['X_train'], dataArray[currentFold]['y_train'], epochs=n_epochs,
              batch_size=50, 
              validation_data=(dataArray[currentFold]['X_test'], dataArray[currentFold]['y_test']),
              callbacks=[time_callback, early_stopping_callback, checkpoint_callback])

    stoppingEpoch=early_stopping_callback.stopped_epoch
    modelTimes = time_callback.times
    
    historyF1 = modelHistory.history['val_f1_m']
    historyPrecision = modelHistory.history['val_precision_m']
    historyRecall = modelHistory.history['val_recall_m']
    historyAccuracy = modelHistory.history['val_acc']
    historyTP = modelHistory.history['val_tp_m']
    historyFP = modelHistory.history['val_fp_m']
    historyTN = modelHistory.history['val_tn_m']
    historyFN = modelHistory.history['val_fn_m']
    
    convergenceEpochs=str(historyAccuracy.index(max(historyAccuracy)))
    totalTrainingTime=np.sum(np.array(modelTimes[int(convergenceEpochs)]).astype(np.float))
    print('type(totalTrainingTime): '+str(type(totalTrainingTime)))
    print('type(convergenceEpochs): '+str(type(convergenceEpochs)))
    meanTimePerEpoch=totalTrainingTime/int(convergenceEpochs)
    

    with open(resultsFilename, "a") as text_file:
        print(f"Training complete for fold {str(currentFold)}\n", file=text_file)
        print(f"Epoch Times: {str(modelTimes[0:int(convergenceEpochs)])}\n", file=text_file)
        print(f"Fold {str(currentFold)} Test Metrics:\n", file=text_file)
        print(f"Fold TP: {str(historyTP)}\nFold TN: {str(historyTN)}\nFold FP: {str(historyFP)}\nFold FN: {str(historyFN)}\n", file=text_file)
        print(f"Fold Accuracy: {str(historyAccuracy)}\nFold Precision: {str(historyPrecision)}\nFold Recall: {str(historyRecall)}\nFold F1: {str(historyF1)}\n", file=text_file)
        print(f"Accuracy Maxes at Epoch: {str(convergenceEpochs)}\n", file=text_file)
        print(f"Early stopping at epoch: {str(stoppingEpoch)}\n", file=text_file)
        print(f"Training Epochs until max accuracy: {str(convergenceEpochs)}\n", file=text_file)
        print(f"Total Training Time: {str(totalTrainingTime)}\n", file=text_file)
        print(f"Mean Time per Epoch: {str(meanTimePerEpoch)}\n", file=text_file)

    # load the saved model
    saved_model = load_model('optimal_model.h5', custom_objects={"f1_m": f1_m,
                                                              "precision_m": precision_m,
                                                              "recall_m": recall_m,
                                                            "tp_m":tp_m, 
                                                             "fp_m":fp_m,
                                                             "tn_m":tn_m,
                                                             "fn_m":fn_m
                                                            })

    loss, accuracy, f1_score, precision, recall, tp, fp, tn, fn  = saved_model.evaluate(dataArray[currentFold]['X_test'], dataArray[currentFold]['y_test'], 
                            verbose=1)
    
    predictions=(saved_model.predict(dataArray[currentFold]['X_test'])>0.5).reshape(-1)
    truelabels=dataArray[currentFold]['y_test']==1
    tp=np.sum(np.logical_and(predictions, truelabels))
    tn=np.sum(np.logical_and(np.invert(predictions), np.invert(truelabels)))
    fp=np.sum(np.logical_and(predictions, np.invert(truelabels)))
    fn=np.sum(np.logical_and(np.invert(predictions), (truelabels)))
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    accuracy = (tp+tn)/(tp+tn+fp+fn)
    f1_score = (2*precision*recall)/(precision+recall)

    
    with open(resultsFilename, "a") as text_file:
        print(f"Final Test Metrics for {str(currentFold)}:\n", file=text_file)
        print(f"TP: {str(tp)}\n TN: {str(tn)}\n FP: {str(fp)}\n FN: {str(fn)}\n", file=text_file)
        print(f"Accuracy: {str(accuracy)}\n Precision: {str(precision)}\n Recall: {str(recall)}\n F1: {str(f1_score)}\n", file=text_file)

    overallPrecisionList.append(historyPrecision)
    overallRecallList.append(historyRecall)
    overallAccuracyList.append(historyAccuracy)
    overallF1List.append(historyF1)
    overallTPList.append(historyTP)
    overallTNList.append(historyTN)
    overallFPList.append(historyFP)
    overallFNList.append(historyFN)
    overallConvergenceEpochList.append(convergenceEpochs)
    overallTrainingTimeList.append(totalTrainingTime)
    overallMeanEpochTimeList.append(meanTimePerEpoch)
    
precisionMeanOverFolds=np.average(np.array(overallPrecisionList), axis=0)
recallMeanOverFolds=np.average(np.array(overallRecallList), axis=0)
accuracyMeanOverFolds=np.average(np.array(overallAccuracyList), axis=0)
F1MeanOverFolds=np.average(np.array(overallF1List), axis=0)
TPMeanOverFolds = np.average(np.array(overallTPList), axis=0)
TNMeanOverFolds = np.average(np.array(overallTNList), axis=0)
FPMeanOverFolds = np.average(np.array(overallFPList), axis=0)
FNMeanOverFolds = np.average(np.array(overallFNList), axis=0)
convergenceMeanOverFolds = np.mean(np.array(overallConvergenceEpochList).astype(np.float))
totalTrainingTimeMeanOverFolds = np.mean(np.array(overallTrainingTimeList).astype(np.float))
EpochTimeMeanOverFolds = np.mean(np.array(overallMeanEpochTimeList).astype(np.float))


maxAccuracyIndex=int(np.argmax(accuracyMeanOverFolds))


with open(str(resultsFilename), "a") as text_file:
    print(f"Training complete for all folds.", file=text_file)
    print(f"Mean Test Metrics Over All Folds:\n", file=text_file)
    print(f"Final Accuracy: {str(accuracyMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final Precision: {str(precisionMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final Recall: {str(recallMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final F1: {str(F1MeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final TP: {str(TPMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final FP: {str(FPMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final TN: {str(TNMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Final FN: {str(FNMeanOverFolds[maxAccuracyIndex])}\n", file=text_file)
    print(f"Obs. Until Max Accuracy: {str(convergenceMeanOverFolds)}\n", file=text_file)
    print(
        f"TP: {str(list(TPMeanOverFolds))}\nTN: {str(list(TNMeanOverFolds))}\nFP: {str(list(FPMeanOverFolds))}\nFN: {str(list(FNMeanOverFolds))}\n",
        file=text_file)
    print(
        f"Accuracy: {str(list(accuracyMeanOverFolds))}\nPrecision: {str(list(precisionMeanOverFolds))}\nRecall: {str(list(recallMeanOverFolds))}\nF1: {str(list(F1MeanOverFolds))}\n",
        file=text_file)
# Out:
# Results file exists
# Begin training for fold 0
#
# y_true - 1 Tensor("metrics_10/tn_m/sub:0", shape=(?, ?), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 16, 128)           3998208
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 30)                3870
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 4,133,693
# Trainable params: 4,133,693
# Non-trainable params: 0
# _________________________________________________________________
# None
# input data shape: (62, 16, 7680)
# Train on 62 samples, validate on 17 samples
# epoch time start: 1578163384.3404896
# Epoch 1/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.6872 - acc: 0.5400 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - tp_m: 0.0000e+00 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 23.0000epoch time measured: 2.773386001586914
#
# Epoch 00001: val_acc improved from -inf to 0.52941, saving model to optimal_model.h5
# 62/62 [==============================] - 4s 69ms/step - loss: 0.6818 - acc: 0.5645 - f1_m: 0.1548 - precision_m: 0.1290 - recall_m: 0.1935 - tp_m: 1.5484 - fp_m: 0.7742 - tn_m: 21.7742 - fn_m: 18.5484 - val_loss: 0.7157 - val_acc: 0.5294 - val_f1_m: 0.6923 - val_precision_m: 0.5294 - val_recall_m: 1.0000 - val_tp_m: 9.0000 - val_fp_m: 8.0000 - val_tn_m: 0.0000e+00 - val_fn_m: 0.0000e+00
# epoch time start: 1578163388.6368701
# Epoch 2/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.6302 - acc: 0.4600 - f1_m: 0.6301 - precision_m: 0.4600 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 27.0000 - tn_m: 0.0000e+00 - fn_m: 0.0000e+00epoch time measured: 0.508866548538208
#
# Epoch 00002: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.5971 - acc: 0.5161 - f1_m: 0.6712 - precision_m: 0.5117 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 22.3548 - tn_m: 0.1935 - fn_m: 0.0000e+00 - val_loss: 0.7007 - val_acc: 0.5294 - val_f1_m: 0.6923 - val_precision_m: 0.5294 - val_recall_m: 1.0000 - val_tp_m: 9.0000 - val_fp_m: 8.0000 - val_tn_m: 0.0000e+00 - val_fn_m: 0.0000e+00
# epoch time start: 1578163389.1473024
# Epoch 3/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.4704 - acc: 0.8600 - f1_m: 0.8727 - precision_m: 0.7742 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 7.0000 - tn_m: 19.0000 - fn_m: 0.0000e+00epoch time measured: 0.5037338733673096
#
# Epoch 00003: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.4515 - acc: 0.8871 - f1_m: 0.8974 - precision_m: 0.8179 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 5.6452 - tn_m: 16.2903 - fn_m: 0.0000e+00 - val_loss: 0.6781 - val_acc: 0.5294 - val_f1_m: 0.6667 - val_precision_m: 0.5333 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 7.0000 - val_tn_m: 1.0000 - val_fn_m: 1.0000
# epoch time start: 1578163389.6528175
# Epoch 4/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.3116 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.494936466217041
#
# Epoch 00004: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.3032 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 0.6655 - val_acc: 0.5294 - val_f1_m: 0.6364 - val_precision_m: 0.5385 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 2.0000
# epoch time start: 1578163390.1493006
# Epoch 5/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.2142 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5147650241851807
#
# Epoch 00005: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.2038 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 0.6644 - val_acc: 0.5294 - val_f1_m: 0.6364 - val_precision_m: 0.5385 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 2.0000
# epoch time start: 1578163390.6655593
# Epoch 6/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.1392 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4951648712158203
#
# Epoch 00006: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.1309 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 0.6789 - val_acc: 0.5294 - val_f1_m: 0.6364 - val_precision_m: 0.5385 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 2.0000
# epoch time start: 1578163391.1623738
# Epoch 7/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0879 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.5006327629089355
#
# Epoch 00007: val_acc improved from 0.52941 to 0.58824, saving model to optimal_model.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0817 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 0.7143 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163391.8845942
# Epoch 8/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0540 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.0000 - fp_m: 0.0000e+00 - tn_m: 28.0000 - fn_m: 0.0000e+00epoch time measured: 0.495682954788208
#
# Epoch 00008: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0502 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 19.4839 - fp_m: 0.0000e+00 - tn_m: 23.1613 - fn_m: 0.0000e+00 - val_loss: 0.7687 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163392.3819184
# Epoch 9/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0324 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.4996981620788574
#
# Epoch 00009: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0312 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 0.8351 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163392.8832095
# Epoch 10/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0219 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.4948866367340088
#
# Epoch 00010: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0203 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 0.9044 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163393.380171
# Epoch 11/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0140 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.4983384609222412
#
# Epoch 00011: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0135 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 0.9708 - val_acc: 0.5294 - val_f1_m: 0.6667 - val_precision_m: 0.5333 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 7.0000 - val_tn_m: 1.0000 - val_fn_m: 1.0000
# epoch time start: 1578163393.880089
# Epoch 12/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0090 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.4974849224090576
#
# Epoch 00012: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0094 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.0307 - val_acc: 0.5294 - val_f1_m: 0.6667 - val_precision_m: 0.5333 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 7.0000 - val_tn_m: 1.0000 - val_fn_m: 1.0000
# epoch time start: 1578163394.3790727
# Epoch 13/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0067 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.5016791820526123
#
# Epoch 00013: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0070 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.0817 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163394.8825681
# Epoch 14/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0059 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.49031925201416016
#
# Epoch 00014: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0055 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.1235 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163395.3743398
# Epoch 15/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0046 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5093245506286621
#
# Epoch 00015: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0044 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.1589 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163395.885293
# Epoch 16/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0034 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.4964451789855957
#
# Epoch 00016: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0036 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.1883 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163396.3831568
# Epoch 17/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0031 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.48754096031188965
#
# Epoch 00017: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0031 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.2124 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163396.8723795
# Epoch 18/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0025 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.4906167984008789
#
# Epoch 00018: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0026 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.2326 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163397.3648279
# Epoch 19/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0024 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.49359774589538574
#
# Epoch 00019: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0023 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.2496 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163397.8601208
# Epoch 20/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0020 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.4859468936920166
#
# Epoch 00020: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0021 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.2642 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163398.3476024
# Epoch 21/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0019 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4988212585449219
#
# Epoch 00021: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.2765 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163398.8478005
# Epoch 22/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0017 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4920840263366699
#
# Epoch 00022: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.2869 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163399.3414288
# Epoch 23/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0015 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.5029475688934326
#
# Epoch 00023: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0016 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.2956 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163399.8458493
# Epoch 24/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0014 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.49999141693115234
#
# Epoch 00024: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0015 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.3028 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163400.3473704
# Epoch 25/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0014 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.5393068790435791
#
# Epoch 00025: val_acc did not improve
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0014 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.3089 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163400.888626
# Epoch 26/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0014 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.49596166610717773
#
# Epoch 00026: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3144 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163401.386333
# Epoch 27/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0013 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5084402561187744
#
# Epoch 00027: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0012 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3196 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163401.8966339
# Epoch 28/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0012 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5152013301849365
#
# Epoch 00028: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0012 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3247 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163402.4135582
# Epoch 29/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0011 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.5084640979766846
#
# Epoch 00029: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0011 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.3296 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163402.9236922
# Epoch 30/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0011 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5158469676971436
#
# Epoch 00030: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0011 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3342 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163403.4409802
# Epoch 31/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0010 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.49645042419433594
#
# Epoch 00031: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.3385 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163403.9391398
# Epoch 32/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0010 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.4932382106781006
#
# Epoch 00032: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.3424 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163404.4342752
# Epoch 33/250
# 50/62 [=======================>......] - ETA: 0s - loss: 0.0010 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.0000 - fp_m: 0.0000e+00 - tn_m: 29.0000 - fn_m: 0.0000e+00epoch time measured: 0.5139544010162354
#
# Epoch 00033: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 9.9033e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 18.8710 - fp_m: 0.0000e+00 - tn_m: 23.7742 - fn_m: 0.0000e+00 - val_loss: 1.3463 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163404.949948
# Epoch 34/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.2848e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.5255293846130371
#
# Epoch 00034: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 9.5915e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.3503 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163405.477232
# Epoch 35/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.3095e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.49337220191955566
#
# Epoch 00035: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.3220e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.3542 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163405.9722424
# Epoch 36/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.9917e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.49268317222595215
#
# Epoch 00036: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.0650e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.3579 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163406.4665074
# Epoch 37/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.9119e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4970238208770752
#
# Epoch 00037: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 8.8269e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3615 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163406.9654346
# Epoch 38/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.3197e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.4993300437927246
#
# Epoch 00038: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 8.5957e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.3649 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163407.46643
# Epoch 39/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.6074e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.49591612815856934
#
# Epoch 00039: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 8.3892e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.3682 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163407.9641159
# Epoch 40/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.3268e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.5163371562957764
#
# Epoch 00040: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 8.1859e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.3717 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163408.4819777
# Epoch 41/250
# 50/62 [=======================>......] - ETA: 0s - loss: 8.2591e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.5017669200897217
#
# Epoch 00041: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 7.9960e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.3755 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163408.9856637
# Epoch 42/250
# 50/62 [=======================>......] - ETA: 0s - loss: 7.9341e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5135347843170166
#
# Epoch 00042: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 7.8132e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.3794 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163409.501095
# Epoch 43/250
# 50/62 [=======================>......] - ETA: 0s - loss: 7.5188e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.5029501914978027
#
# Epoch 00043: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 7.6387e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.3833 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163410.0062919
# Epoch 44/250
# 50/62 [=======================>......] - ETA: 0s - loss: 7.8458e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.0000 - fp_m: 0.0000e+00 - tn_m: 29.0000 - fn_m: 0.0000e+00epoch time measured: 0.5065433979034424
#
# Epoch 00044: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 7.4775e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 18.8710 - fp_m: 0.0000e+00 - tn_m: 23.7742 - fn_m: 0.0000e+00 - val_loss: 1.3870 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163410.5145538
# Epoch 45/250
# 50/62 [=======================>......] - ETA: 0s - loss: 7.2608e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.48773694038391113
#
# Epoch 00045: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 7.3140e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.3909 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163411.0041647
# Epoch 46/250
# 50/62 [=======================>......] - ETA: 0s - loss: 7.0608e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.488131046295166
#
# Epoch 00046: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 7.1601e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.3946 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163411.493976
# Epoch 47/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.8411e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.48770809173583984
#
# Epoch 00047: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 7.0119e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.3982 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163411.9831338
# Epoch 48/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.7592e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.4814159870147705
#
# Epoch 00048: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 6.8685e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.4015 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163412.466094
# Epoch 49/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.6767e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.4974992275238037
#
# Epoch 00049: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 6.7294e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.4046 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163412.9653246
# Epoch 50/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.7104e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5096356868743896
#
# Epoch 00050: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 6.5966e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.4076 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163413.476669
# Epoch 51/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.4512e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4979870319366455
#
# Epoch 00051: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 6.4653e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.4106 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163413.9761963
# Epoch 52/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.2022e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.5221526622772217
#
# Epoch 00052: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 6.3389e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.4134 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163414.5000515
# Epoch 53/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.3007e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.5011982917785645
#
# Epoch 00053: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 6.2197e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.4162 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163415.002909
# Epoch 54/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.0992e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.49807047843933105
#
# Epoch 00054: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 6.1013e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.4190 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163415.5031276
# Epoch 55/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.0416e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.49535655975341797
#
# Epoch 00055: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.9881e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.4218 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163416.0000262
# Epoch 56/250
# 50/62 [=======================>......] - ETA: 0s - loss: 6.1107e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.0000 - fp_m: 0.0000e+00 - tn_m: 28.0000 - fn_m: 0.0000e+00epoch time measured: 0.4896225929260254
#
# Epoch 00056: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.8799e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 19.4839 - fp_m: 0.0000e+00 - tn_m: 23.1613 - fn_m: 0.0000e+00 - val_loss: 1.4247 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163416.4912574
# Epoch 57/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.8275e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4981207847595215
#
# Epoch 00057: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.7723e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.4279 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163416.9910853
# Epoch 58/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.8298e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.5012369155883789
#
# Epoch 00058: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 5.6710e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.4311 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163417.4940517
# Epoch 59/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.4615e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.5076417922973633
#
# Epoch 00059: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 5.5707e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.4343 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163418.003416
# Epoch 60/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.5729e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.0000 - fp_m: 0.0000e+00 - tn_m: 28.0000 - fn_m: 0.0000e+00epoch time measured: 0.500903844833374
#
# Epoch 00060: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 5.4761e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 19.4839 - fp_m: 0.0000e+00 - tn_m: 23.1613 - fn_m: 0.0000e+00 - val_loss: 1.4375 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163418.5060093
# Epoch 61/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.4750e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4927403926849365
#
# Epoch 00061: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.3827e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.4409 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163419.0007715
# Epoch 62/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.3688e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.49272632598876953
#
# Epoch 00062: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.2917e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.4444 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163419.4952657
# Epoch 63/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.1419e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.49512457847595215
#
# Epoch 00063: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.2032e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.4480 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163419.9922833
# Epoch 64/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.0861e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.48735737800598145
#
# Epoch 00064: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 5.1178e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.4513 - val_acc: 0.5882 - val_f1_m: 0.6957 - val_precision_m: 0.5714 - val_recall_m: 0.8889 - val_tp_m: 8.0000 - val_fp_m: 6.0000 - val_tn_m: 2.0000 - val_fn_m: 1.0000
# epoch time start: 1578163420.4813552
# Epoch 65/250
# 50/62 [=======================>......] - ETA: 0s - loss: 5.0131e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4995856285095215
#
# Epoch 00065: val_acc did not improve
# ...
#
# Epoch 00229: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.1125e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.7562 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163929.2666035
# Epoch 230/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0941e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.5027351379394531
#
# Epoch 00230: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 1.1045e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7574 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163929.7714643
# Epoch 231/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.1062e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.47773170471191406
#
# Epoch 00231: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0969e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.7586 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163930.2509644
# Epoch 232/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.1005e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.4834253787994385
#
# Epoch 00232: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0892e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.7599 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163930.7360604
# Epoch 233/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0410e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.48446011543273926
#
# Epoch 00233: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0814e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.7611 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163931.2224734
# Epoch 234/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0480e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 28.0000 - fp_m: 0.0000e+00 - tn_m: 22.0000 - fn_m: 0.0000e+00epoch time measured: 0.5238902568817139
#
# Epoch 00234: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 1.0739e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.1613 - fp_m: 0.0000e+00 - tn_m: 19.4839 - fn_m: 0.0000e+00 - val_loss: 1.7622 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163931.748165
# Epoch 235/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0596e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.48576998710632324
#
# Epoch 00235: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0664e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7633 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163932.235552
# Epoch 236/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0528e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4912898540496826
#
# Epoch 00236: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0589e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7644 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163932.72848
# Epoch 237/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0679e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 23.0000 - fp_m: 0.0000e+00 - tn_m: 27.0000 - fn_m: 0.0000e+00epoch time measured: 0.4799659252166748
#
# Epoch 00237: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0515e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.0968 - fp_m: 0.0000e+00 - tn_m: 22.5484 - fn_m: 0.0000e+00 - val_loss: 1.7655 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163933.2099037
# Epoch 238/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0312e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4887275695800781
#
# Epoch 00238: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0441e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7666 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163933.7001452
# Epoch 239/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0345e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.502500057220459
#
# Epoch 00239: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 1.0369e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.7677 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163934.2043228
# Epoch 240/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0447e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.49480533599853516
#
# Epoch 00240: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0298e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.7689 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163934.700683
# Epoch 241/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0070e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.4917924404144287
#
# Epoch 00241: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0226e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.7700 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163935.1940093
# Epoch 242/250
# 50/62 [=======================>......] - ETA: 0s - loss: 1.0316e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.0000 - fp_m: 0.0000e+00 - tn_m: 28.0000 - fn_m: 0.0000e+00epoch time measured: 0.4826946258544922
#
# Epoch 00242: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0157e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 19.4839 - fp_m: 0.0000e+00 - tn_m: 23.1613 - fn_m: 0.0000e+00 - val_loss: 1.7711 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163935.678523
# Epoch 243/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.9581e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.5128130912780762
#
# Epoch 00243: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 1.0087e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7723 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163936.192974
# Epoch 244/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.9716e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.48593831062316895
#
# Epoch 00244: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 1.0018e-04 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7735 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163936.6803954
# Epoch 245/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.9091e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 25.0000 - fp_m: 0.0000e+00 - tn_m: 25.0000 - fn_m: 0.0000e+00epoch time measured: 0.4927330017089844
#
# Epoch 00245: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.9504e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.3226 - fp_m: 0.0000e+00 - tn_m: 21.3226 - fn_m: 0.0000e+00 - val_loss: 1.7746 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163937.174522
# Epoch 246/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.7188e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.519599199295044
#
# Epoch 00246: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 9.8833e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.7758 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163937.6958218
# Epoch 247/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.7460e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.4856548309326172
#
# Epoch 00247: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.8161e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7769 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163938.1829405
# Epoch 248/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.6106e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 26.0000 - fp_m: 0.0000e+00 - tn_m: 24.0000 - fn_m: 0.0000e+00epoch time measured: 0.5018064975738525
#
# Epoch 00248: val_acc did not improve
# 62/62 [==============================] - 1s 8ms/step - loss: 9.7506e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 21.9355 - fp_m: 0.0000e+00 - tn_m: 20.7097 - fn_m: 0.0000e+00 - val_loss: 1.7780 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163938.686697
# Epoch 249/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.5589e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 27.0000 - fp_m: 0.0000e+00 - tn_m: 23.0000 - fn_m: 0.0000e+00epoch time measured: 0.48720788955688477
#
# Epoch 00249: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.6838e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 22.5484 - fp_m: 0.0000e+00 - tn_m: 20.0968 - fn_m: 0.0000e+00 - val_loss: 1.7791 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# epoch time start: 1578163939.17724
# Epoch 250/250
# 50/62 [=======================>......] - ETA: 0s - loss: 9.6731e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 24.0000 - fp_m: 0.0000e+00 - tn_m: 26.0000 - fn_m: 0.0000e+00epoch time measured: 0.49431395530700684
#
# Epoch 00250: val_acc did not improve
# 62/62 [==============================] - 0s 8ms/step - loss: 9.6198e-05 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - tp_m: 20.7097 - fp_m: 0.0000e+00 - tn_m: 21.9355 - fn_m: 0.0000e+00 - val_loss: 1.7801 - val_acc: 0.5882 - val_f1_m: 0.6667 - val_precision_m: 0.5833 - val_recall_m: 0.7778 - val_tp_m: 7.0000 - val_fp_m: 5.0000 - val_tn_m: 3.0000 - val_fn_m: 2.0000
# type(totalTrainingTime): <class 'numpy.float64'>
# type(convergenceEpochs): <class 'str'>
# y_true - 1 Tensor("metrics_17/tn_m/sub:0", shape=(?, ?), dtype=float32)
# 17/17 [==============================] - 1s 81ms/step

# %%
import ast
f = open(resultsFilename)
accList=list()
precisionList=list()
recallList=list()
f1List=list()

for line in f:
    if(str(line[0:13])=='Fold Accuracy'):
        listStart1=line.find('[')
        listEnd1=line.find(']')
        list1=ast.literal_eval(line[listStart1:listEnd1+1])
        accList.append(list(list1))
    if(str(line[0:14])=='Fold Precision'):
        listStart2=line.find('[')
        listEnd2=line.find(']')
        list2=ast.literal_eval(line[listStart2:listEnd2+1])
        precisionList.append(list(list2))
    if(str(line[0:11])=='Fold Recall'):
        listStart3=line.find('[')
        listEnd3=line.find(']')
        list3=ast.literal_eval(line[listStart3:listEnd3+1])
        recallList.append(list(list3))
    if(str(line[0:7])=='Fold F1'):
        listStart4=line.find('[')
        listEnd4=line.find(']')
        list4=ast.literal_eval(line[listStart4:listEnd4+1])
        f1List.append(list(list4))
f.close()

# %%
import statistics

# %%
averageAccuracy = [statistics.mean(k) for k in zip(accList[0],accList[1],accList[2],accList[3])]
averagePrecisions=[statistics.mean(k) for k in zip(precisionList[0],precisionList[1],precisionList[2],precisionList[3])]
averageRecall=[statistics.mean(k) for k in zip(recallList[0],recallList[1],recallList[2],recallList[3])]
averageF1s=[statistics.mean(k) for k in zip(f1List[0],f1List[1],f1List[2],f1List[3])]

# %%
with open(resultsFilename, "a") as text_file:
    print(f"Average Accuracies List: {str(averageAccuracy)}", file=text_file)
    print(f"Average Precisions List: {str(averagePrecisions)}", file=text_file)
    print(f"Average Recalls List: {str(averageRecall)}", file=text_file)
    print(f"Average F1 List: {str(averageF1s)}", file=text_file)
